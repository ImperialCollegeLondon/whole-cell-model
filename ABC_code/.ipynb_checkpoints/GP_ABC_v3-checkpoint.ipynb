# %%
using GpABC,OrdinaryDiffEq, Distances, Distributions, Plots, StatsBase, Printf, ODE, DifferentialEquations, Statistics, ModelingToolkit, CSV
using DelimitedFiles, StatsPlots
import Base.Iterators
include("setup_ABC.jl")
gr()

function log_euclidean(x,y)
    output = sqrt(sum((log10.(x.+0.00001) - log10.(y.+0.00001)) .^ 2))
    return (output/size(x)[1]) #average by the length of the vector
end
# Out:
# log_euclidean (generic function with 1 method)

# %%
@parameters t

@variables s_out(t) rmr(t) em(t) rmq(t) rmt(t) et(t) rmm(t) mt(t) mm(t) q(t) si(t) mq(t) mr(t) r(t) NH4(t) nit_mrna(t) nit_mrna_ribo(t) nit(t) NH4_ex(t) N(t) a(t) AA(t) AA_prot(t) AA_mrna(t) AA_mrna_ribo(t)

#############check the last parameter k_ribo_a
###############

@parameters k_cat_AA k_a_NH4 k_NH4 k_a_AA k_NH4_AA k_a #these are the parameters to be varied in ABC
gam= (gmax*a*AA)/(k_ribo_a*k_ribo_a_AA+k_ribo_a_AA*a+k_ribo_AA_a*AA+a*AA) #updated gamma equation that uses both ATP and AA
ttrate= (rmq + rmr + rmt + rmm + nit_mrna_ribo+AA_mrna_ribo)*gam #total translation rate (sum of the mRNA/ribosome complexes times translation rate)
lam= ttrate/M #lambda is the growth rate
nucat= em*vm*si/(Km + abs(si))
AA_vo = ((k_cat_AA*2*a*NH4)/(k_a_NH4*k_a))/(1+(1+(AA/k_a_AA))+(NH4/k_a_NH4)+(1+(AA/k_NH4_AA))+(NH4/k_NH4))
new_AA = AA_vo*AA_prot
AA_a_use = new_AA*2 #each AA produced uses x number of ATP molecules
AA_NH4_use = new_AA*2 #each AA produced uses 2 NH4 molecules
export_rate = 0 #export rate of NH4
fixation = 0
death_rate = 0
k_ribo_a_AA = 10000.0
k_ribo_AA_a = 10000.0
k_ribo_a = 10.0

@derivatives D'~t

eqs = [
    D(s_out)~ 0 #((-et*vt*s_out/(Kt+s_out))*N)-ds*s_out+(export_rate*NH4*50)+1e7
    D(rmr)~ kb*r*mr-ku*rmr-(gam/nr)*rmr-lam*rmr
    D(em)~ (gam/nx)*rmm-lam*em
    D(rmq)~ kb*r*mq-ku*rmq-(gam/nx)*rmq-lam*rmq
    D(rmt)~ kb*r*mt-ku*rmt-gam/nx*rmt-lam*rmt
    D(et)~ (gam/nx)*rmt-lam*et
    D(rmm)~ kb*r*mm-ku*rmm-gam/nx*rmm-lam*rmm
    D(mt)~ (we*a/(thetax+a))+ku*rmt+(gam/nx)*rmt-kb*r*mt-dm*mt-lam*mt
    D(mm)~ (we*a/(thetax+a))+ku*rmm+(gam/nx)*rmm-kb*r*mm-dm*mm-lam*mm
    D(q)~ (gam/nx)*rmq-lam*q
    D(si)~ (et*vt*s_out/(Kt+s_out))-nucat-lam*si
    D(mq)~ (wq*a/(thetax+a)/(1+(q/Kq)^nq))+ku*rmq+(gam/nx)*rmq-kb*r*mq-dm*mq-lam*mq
    D(mr)~ (wr*a/(thetar+a))+ku*rmr+(gam/nr)*rmr-kb*r*mr-dm*mr-lam*mr
    D(r)~ ku*rmr+ku*rmt+ku*rmm+ku*rmq+(gam/nr)*rmr+(gam/nr)*rmr+(gam/nx)*rmt+(gam/nx)*rmm+(gam/nx)*rmq-kb*r*mr-kb*r*mt-kb*r*mm-kb*r*mq+ku*nit_mrna_ribo+(gam/nx)*nit_mrna_ribo-kb*r*nit_mrna+ku*AA_mrna_ribo+(gam/nx)*AA_mrna_ribo-kb*r*AA_mrna-lam*r
    D(NH4)~ 0 #fixation*nit-export_rate*NH4-lam*NH4-AA_NH4_use+2.3e6
    D(nit_mrna)~ 0 #(v_nit*a/(thetax + a))+(ku*nit_mrna_ribo)+(gam/nx*nit_mrna_ribo)-(kb*r*nit_mrna)-(dm*nit_mrna)-(lam*nit_mrna) #num of free nitrogenase coding mRNA
    D(nit_mrna_ribo)~ 0 #(kb*r*nit_mrna)-(ku*nit_mrna_ribo)-(gam/nx*nit_mrna_ribo)-(lam*nit_mrna_ribo) #num of nit mRNA-ribosome complexes
    D(nit)~ 0 #(gam/nx)*nit_mrna_ribo-lam*nit #num of nitrogenase proteins
    D(NH4_ex)~ 0 #(export_rate*NH4)#total num of NH4 molecules exported this timestep
    D(N)~ 0 #lam*N-death_rate*N #the change in num of bacterial cells instead of just loss to dilution
    D(a)~ ns*nucat-ttrate-fixation*nit-AA_a_use-lam*a
    D(AA)~ new_AA-ttrate-lam*AA
    D(AA_prot)~ (gam/nx)*AA_mrna_ribo-lam*AA_prot
    D(AA_mrna)~ ((w_AA*a/(thetax+a)))+(ku*AA_mrna_ribo)+(gam/nx*AA_mrna_ribo)-(kb*r*AA_mrna)-(dm*AA_mrna)-(lam*AA_mrna)
    D(AA_mrna_ribo)~ (kb*r*AA_mrna)-(ku*AA_mrna_ribo)-(gam/nx*AA_mrna_ribo)-(lam*AA_mrna_ribo)
];

println("System defined successfully")
# Out:
# System defined successfully

# %%
de = ODESystem(eqs, t, [s_out, rmr, em, rmq, rmt, 
        et, rmm, mt, mm, q, si, mq, mr, r, NH4, nit_mrna,
        nit_mrna_ribo, nit, NH4_ex, N, a, AA, AA_prot,
        AA_mrna, AA_mrna_ribo],[k_cat_AA,k_a_NH4 ,k_NH4, k_a_AA, k_NH4_AA, k_a])

f = ODEFunction(de)
p = [10.0,10.0,10.0,10.0,10.0,10.0]
burn_in_prob_abc = ODEProblem(f, init, (0.,10000.0),p) #set up the burn in problem

println("burning in model")
sol = solve(burn_in_prob_abc)
println("success")
step_num = size(sol,2)
final_state =sol[step_num] #run the burn in stage and collect the end state to use as new initial values

prob_abc = ODEProblem(f, final_state, (0.,10000.0),p) #the problem to run ABC on using the burned in initial values
# Out:
# burning in model
# success
# ODEProblem with uType Array{Float64,1} and tType Float64. In-place: true
# timespan: (0.0, 10000.0)
# u0: [1.0e11, 1433.7935898638818, 547.7276435794657, 1352.8302553986343, 7.160976755336487, 547.7276435794676, 7.16097675533649, 39.131453539252924, 39.13145353925297, 103475.06368697481  …  3.2845105566973926e-14, -3.242118686375807e-14, 0.0, 0.0, 1.0, 879.6320760648405, 4.328441256015495e9, 119095.04047006265, 8508.539047716775, 1557.0454156898122]

# %%
function simulator_function_lm(params, time1= 10000.0)
    global k_cat_AA = params[1]
    global k_a_NH4 = 10. #params[2]
    global k_NH4 = 10. #params[3]
    global k_a_AA = 10. #params[4]
    global k_NH4_AA = 10.# params[5]
    global k_a = 10. #params[6]
    prob = ODEProblem(AA_simple,init,(0.,time1))
    sol = ODE.solve(prob, saveat = 1.)
    return Array{Float64, 2}(sol)
end
# Out:
# simulator_function_lm (generic function with 2 methods)

# %%
population_colors=["#FF2F4E", "#D0001F", "#A20018", "#990017", "#800013"]

threshold_schedule = [0.01,0.005,0.001, 0.0007, 0.0005, 0.0001];
priors = [Uniform(0., 20.0)]#, Uniform(0.,20.0), Uniform(0., 20.0)]#,
#     Uniform(2., 30.), Uniform(2., 30.), Uniform(2., 30.)]
n_particles = 300

real_param_vect = []
est_param_mean = []
est_param_mode = []
difference_vect = []
final_popns = []
# Out:
# 0-element Array{Any,1}

# %%
for i in range(1,stop = 20)

#generate dummy data with 1 random param between 0 and 20
params_lm = rand(1)*20
results = simulator_function_lm(params_lm);

#run abc smc to try and recreate the 1 random param value
sim_abcsmc_res = SimulatedABCSMC(results,
    simulator_function_lm,
    priors,
    threshold_schedule,
    n_particles,
    distance_function = log_euclidean,
    max_iter=convert(Int, 2e6),
    write_progress=true)

mean1 = mean(sim_abcsmc_res.population[6][:,1])
mode1 = mode(sim_abcsmc_res.population[6][:,1])
    ##pull out maximum as well as the mean of the final pop
    
println("estimated paramter mean is $mean1, mode is $mode1")
push!(est_param_mean, mean1)
push!(est_param_mode, mode1)
println("true parameters are $params_lm")
push!(real_param_vect, params_lm)
println("difference for round $i is")
println(euclidean([mean1],params_lm)) #println(euclidean([mean1,mean2,mean3],params_lm))
push!(difference_vect,euclidean([mean1],params_lm))
push!(final_popns, sim_abcsmc_res.population[6][:,1])
    
end
# Out:
# ┌ Info: GpABC rejection simulation. ϵ = 0.01.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\rejection.jl:47
# ┌ Info: GpABC SMC simulation ϵ = 0.005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0007
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 86/1000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 164/2000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# estimated paramter mean is 10.611234898192258, mode is 10.007407230619783
# true parameters are [10.522996479939493]
# difference for round 1 is
# 0.08823841825276446
# ┌ Info: GpABC SMC simulation accepted 262/3000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# ┌ Info: GpABC rejection simulation. ϵ = 0.01.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\rejection.jl:47
# ┌ Info: GpABC SMC simulation ϵ = 0.005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0007
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# estimated paramter mean is 8.117128292389198, mode is 7.799113546337801
# true parameters are [8.087776620336813]
# difference for round 2 is
# 0.029351672052385425
# ┌ Info: GpABC SMC simulation accepted 178/1000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# ┌ Info: GpABC rejection simulation. ϵ = 0.01.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\rejection.jl:47
# ┌ Info: GpABC SMC simulation ϵ = 0.005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0007
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 291/1000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 0.0001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 218/1000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# estimated paramter mean is 1.681427804373495, mode is 1.9766965952550706
# true parameters are [1.6488802229334087]
# difference for round 3 is
# 0.03254758144008618
# ┌ Info: GpABC rejection simulation. ϵ = 0.01.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\rejection.jl:47
# ┌ Info: GpABC SMC simulation ϵ = 0.005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0007
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 283/1000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# estimated paramter mean is 19.37640337744948, mode is 19.89751234779141
# true parameters are [19.614222825876716]
# difference for round 4 is
# 0.2378194484272349
# ┌ Info: GpABC rejection simulation. ϵ = 0.01.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\rejection.jl:47
# ┌ Info: GpABC SMC simulation ϵ = 0.005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0007
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 181/1000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# estimated paramter mean is 12.704781290981002, mode is 12.918545481236254
# true parameters are [12.706448147953505]
# difference for round 5 is
# 0.001666856972503794
# ┌ Info: GpABC rejection simulation. ϵ = 0.01.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\rejection.jl:47
# ┌ Info: GpABC SMC simulation ϵ = 0.005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0007
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 132/1000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 240/2000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# estimated paramter mean is 8.16072686352374, mode is 7.763500620781035
# true parameters are [8.216972184706904]
# difference for round 6 is
# 0.056245321183164165
# ┌ Info: GpABC rejection simulation. ϵ = 0.01.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\rejection.jl:47
# ┌ Info: GpABC SMC simulation ϵ = 0.005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0007
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# estimated paramter mean is 14.843849187218071, mode is 14.895045543091495
# true parameters are [14.829301276158127]
# difference for round 7 is
# 0.01454791105994424
# ┌ Info: GpABC SMC simulation accepted 196/1000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# ┌ Info: GpABC rejection simulation. ϵ = 0.01.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\rejection.jl:47
# ┌ Info: GpABC SMC simulation ϵ = 0.005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0007
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 133/1000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 282/2000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# estimated paramter mean is 2.729704035930486, mode is 2.5464092423330156
# true parameters are [2.6805280628114803]
# difference for round 8 is
# 0.04917597311900579
# ┌ Info: GpABC rejection simulation. ϵ = 0.01.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\rejection.jl:47
# ┌ Info: GpABC SMC simulation ϵ = 0.005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0007
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 298/1000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 0.0005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# estimated paramter mean is 19.426942355918808, mode is 19.148381104149163
# true parameters are [19.58317718444964]
# difference for round 9 is
# 0.15623482853083104
# ┌ Info: GpABC rejection simulation. ϵ = 0.01.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\rejection.jl:47
# ┌ Info: GpABC SMC simulation ϵ = 0.005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0007
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 191/1000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# estimated paramter mean is 12.572517918797908, mode is 12.712544224617115
# true parameters are [12.567263958498852]
# difference for round 10 is
# 0.005253960299056004
# ┌ Info: GpABC rejection simulation. ϵ = 0.01.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\rejection.jl:47
# ┌ Info: GpABC SMC simulation ϵ = 0.005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0007
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 181/1000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# estimated paramter mean is 15.898701277305575, mode is 16.553463177119877
# true parameters are [15.959424606916377]
# difference for round 11 is
# 0.06072332961080207
# ┌ Info: GpABC rejection simulation. ϵ = 0.01.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\rejection.jl:47
# ┌ Info: GpABC SMC simulation ϵ = 0.005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0007
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# estimated paramter mean is 19.29646171645208, mode is 19.25706385918343
# true parameters are [19.232389234269213]
# difference for round 12 is
# 0.06407248218286554
# ┌ Info: GpABC rejection simulation. ϵ = 0.01.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\rejection.jl:47
# ┌ Info: GpABC SMC simulation ϵ = 0.005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0007
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 137/1000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 256/2000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# estimated paramter mean is 12.658960423076628, mode is 12.724507444985331
# true parameters are [12.724290875792846]
# difference for round 13 is
# 0.06533045271621774
# ┌ Info: GpABC rejection simulation. ϵ = 0.01.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\rejection.jl:47
# ┌ Info: GpABC SMC simulation ϵ = 0.005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0007
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 191/1000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# estimated paramter mean is 1.344605728435076, mode is 1.274651747737141
# true parameters are [1.3258176764715257]
# difference for round 14 is
# 0.01878805196355038
# ┌ Info: GpABC rejection simulation. ϵ = 0.01.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\rejection.jl:47
# ┌ Info: GpABC SMC simulation ϵ = 0.005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0007
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 190/1000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# estimated paramter mean is 5.751896040026517, mode is 6.136788005093996
# true parameters are [5.731643465179221]
# difference for round 15 is
# 0.020252574847295257
# ┌ Info: GpABC rejection simulation. ϵ = 0.01.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\rejection.jl:47
# ┌ Info: GpABC SMC simulation ϵ = 0.005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0007
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# estimated paramter mean is 17.48817097858669, mode is 17.467644659702373
# true parameters are [17.538394542151096]
# difference for round 16 is
# 0.05022356356440483
# ┌ Info: GpABC SMC simulation accepted 247/1000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# ┌ Info: GpABC rejection simulation. ϵ = 0.01.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\rejection.jl:47
# ┌ Info: GpABC SMC simulation ϵ = 0.005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0007
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 209/1000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# estimated paramter mean is 15.935598109785046, mode is 16.113103374073585
# true parameters are [15.912329668156588]
# difference for round 17 is
# 0.023268441628458092
# ┌ Info: GpABC rejection simulation. ϵ = 0.01.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\rejection.jl:47
# ┌ Info: GpABC SMC simulation ϵ = 0.005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 67/1000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 130/2000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 202/3000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 283/4000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 0.0007
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 118/1000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# estimated paramter mean is 0.09134329431021787, mode is 0.11528028289997164
# true parameters are [0.08371063913876764]
# difference for round 18 is
# 0.007632655171450231
# ┌ Info: GpABC SMC simulation accepted 229/2000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# ┌ Info: GpABC rejection simulation. ϵ = 0.01.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\rejection.jl:47
# ┌ Info: GpABC SMC simulation ϵ = 0.005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0007
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 192/1000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# estimated paramter mean is 15.022922345287158, mode is 14.683367967735768
# true parameters are [15.027265930627362]
# difference for round 19 is
# 0.004343585340203404
# ┌ Info: GpABC rejection simulation. ϵ = 0.01.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\rejection.jl:47
# ┌ Info: GpABC SMC simulation ϵ = 0.005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0007
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# estimated paramter mean is 10.134116492989268, mode is 9.947199464167866
# true parameters are [10.129533803615809]
# difference for round 20 is
# 0.004582689373458848
# ┌ Info: GpABC SMC simulation accepted 208/1000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238

# %%
boxplot(real_param_vect, final_popns,
xlab = "real value", ylab = "predicted value", label = "",
title = "final epsilon 0.0001")

# %%
scatter(collect(Iterators.flatten(real_param_vect)), collect(Iterators.flatten(est_param_mean)),
    xlab = "real value", ylab = "predicted value", label = "",
title = "final epsilon 0.0001")

# %%
i = 1
println("mean is ",est_param_mean[i]," mode is ", est_param_mode[i])
println("real value is ", real_param_vect[i])
println("median is ", median(final_popns[i]))
histogram(final_popns[i], label = "", xlim=(0,20))
vline!(real_param_vect[i], label ="real value")
vline!([est_param_mean[i]], label = "est mean")
vline!([est_param_mode[i]], label = "est mode")
vline!([median(final_popns[i])], label = "est median")
# Out:
# mean is 16.54941269758187 mode is 16.880946768280108
# real value is [16.573779271848714]
# median is 16.519088075392297

# %%
i = 2
println("mean is ",est_param_mean[i]," mode is ", est_param_mode[i])
println("real value is ", real_param_vect[i])
println("median is ", median(final_popns[i]))
histogram(final_popns[i], label = "", xlim=(0,20))
vline!(real_param_vect[i], label ="real value")
vline!([est_param_mean[i]], label = "est mean")
vline!([est_param_mode[i]], label = "est mode")
vline!([median(final_popns[i])], label = "est median")
# Out:
# mean is 10.26923526336684 mode is 10.46701545080595
# real value is [10.28003711891364]
# median is 10.254565332240272

# %%
i = 3
println("mean is ",est_param_mean[i]," mode is ", est_param_mode[i])
println("real value is ", real_param_vect[i])
println("median is ", median(final_popns[i]))
histogram(final_popns[i], label = "", xlim = (0,20))
vline!(real_param_vect[i], label ="real value")
vline!([est_param_mean[i]], label = "est mean")
vline!([est_param_mode[i]], label = "est mode")
vline!([median(final_popns[i])], label = "est median")
# Out:
# mean is 6.4151529230803295 mode is 6.072478446466162
# real value is [6.462697438689684]
# median is 6.402098682016359

# %%
i = 4
println("mean is ",est_param_mean[i]," mode is ", est_param_mode[i])
println("real value is ", real_param_vect[i])
println("median is ", median(final_popns[i]))
histogram(final_popns[i], label = "", bins = 20)
vline!(real_param_vect[i], label ="real value")
vline!([est_param_mean[i]], label = "est mean")
vline!([est_param_mode[i]], label = "est mode")
vline!([median(final_popns[i])], label = "est median")
# Out:
# mean is 5.5182278608069275 mode is 5.806491327907486
# real value is [5.517473374354891]
# median is 5.5013876269191115

# %%
i = 5
println("mean is ",est_param_mean[i]," mode is ", est_param_mode[i])
println("real value is ", real_param_vect[i])
println("median is ", median(final_popns[i]))
histogram(final_popns[i], label = "", bins = 20)
vline!(real_param_vect[i], label ="real value")
vline!([est_param_mean[i]], label = "est mean")
vline!([est_param_mode[i]], label = "est mode")
vline!([median(final_popns[i])], label = "est median")
# Out:
# mean is 8.197507693445933 mode is 15.051611334476089
# real value is [3.973894292484168]
# median is 8.151353061530116

# %%
function simulator_function_lm(params, time1= 10000.0)
    global k_cat_AA = params[1]
    global k_a_NH4 = params[2]
    global k_NH4 = 10. #params[3]
    global k_a_AA = 10. #params[4]
    global k_NH4_AA = 10.# params[5]
    global k_a = 10. #params[6]
    prob = ODEProblem(AA_simple,init,(0.,time1))
    sol = ODE.solve(prob, saveat = 1.)
    return Array{Float64, 2}(sol)
end
# Out:
# simulator_function_lm (generic function with 2 methods)

# %%
population_colors=["#FF2F4E", "#D0001F", "#A20018", "#990017", "#800013"]

threshold_schedule = [0.005,0.001, 0.0007, 0.0005, 0.0001,0.00005];
priors = [Uniform(0., 20.0), Uniform(0.,20.0)]#, Uniform(0., 20.0)]#,
#     Uniform(2., 30.), Uniform(2., 30.), Uniform(2., 30.)]
n_particles = 300

real_param_vect1 = []
real_param_vect2 = []
difference_vect2 = []
final_popns1 = []
final_popns2 = []
# Out:
# 0-element Array{Any,1}

# %%
for i in range(1,stop = 10)

#generate dummy data with 1 random param between 0 and 20
params_lm = rand(2)*20
results = simulator_function_lm(params_lm);

#run abc smc to try and recreate the 1 random param value
sim_abcsmc_res = SimulatedABCSMC(results,
    simulator_function_lm,
    priors,
    threshold_schedule,
    n_particles,
    distance_function = log_euclidean,
    max_iter=convert(Int, 2e6),
    write_progress=true)

mean1 = mean(sim_abcsmc_res.population[6][:,1])
mode1 = mode(sim_abcsmc_res.population[6][:,1])
println("estimated paramter mean is $mean1, mode is $mode1")
mean2 = mean(sim_abcsmc_res.population[6][:,2])
mode2 = mode(sim_abcsmc_res.population[6][:,2])
println("estimated paramter mean is $mean2, mode is $mode2")
println("true parameters are $params_lm")
push!(real_param_vect1, params_lm[1])
push!(real_param_vect2, params_lm[2])
println("difference for round $i is")
println(euclidean([mean1,mean2],params_lm))
push!(difference_vect2,euclidean([mean1,mean2],params_lm))
    #save the final populations of the two parameters
push!(final_popns1, sim_abcsmc_res.population[6][:,1])
push!(final_popns2, sim_abcsmc_res.population[6][:,2])
end
# Out:
# ┌ Info: GpABC rejection simulation. ϵ = 0.01.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\rejection.jl:47
# ┌ Info: GpABC SMC simulation ϵ = 0.005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Warning: `TruncatedNormal(mu::Real, sigma::Real, a::Real, b::Real)` is deprecated, use `truncated(Normal(mu, sigma), a, b)` instead.
# │   caller = _broadcast_getindex_evalf at broadcast.jl:630 [inlined]
# └ @ Core .\broadcast.jl:630
# ┌ Info: GpABC SMC simulation ϵ = 0.001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0007
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 188/1000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# estimated paramter mean is 17.970583613519505, mode is 19.12534337061875
# estimated paramter mean is 14.770345812151014, mode is 14.966216224777245
# true parameters are [18.20036343779186, 14.96202560287188]
# difference for round 1 is
# 0.2992322004955842
# ┌ Info: GpABC rejection simulation. ϵ = 0.01.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\rejection.jl:47
# ┌ Info: GpABC SMC simulation ϵ = 0.005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0007
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 126/1000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 219/2000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# estimated paramter mean is 11.663542305613445, mode is 8.635803486711199
# estimated paramter mean is 14.473928232279158, mode is 9.979131103281636
# true parameters are [12.247981302210857, 15.26811850234906]
# difference for round 2 is
# 0.9860563502242108
# ┌ Info: GpABC rejection simulation. ϵ = 0.01.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\rejection.jl:47
# ┌ Info: GpABC SMC simulation ϵ = 0.005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0007
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 66/1000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 126/2000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 198/3000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# estimated paramter mean is 11.972311610210385, mode is 15.008702012398116
# estimated paramter mean is 2.642118123265401, mode is 4.013864255016229
# true parameters are [15.229086396546778, 4.055356883712231]
# difference for round 3 is
# 3.5501867278983728
# ┌ Info: GpABC SMC simulation accepted 264/4000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# ┌ Info: GpABC rejection simulation. ϵ = 0.01.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\rejection.jl:47
# ┌ Info: GpABC SMC simulation ϵ = 0.005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 210/1000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 0.0007
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 152/1000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 0.0005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 225/1000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# estimated paramter mean is 1.9872957234303543, mode is 1.8227408104062606
# estimated paramter mean is 14.414851229415756, mode is 15.599249123427098
# true parameters are [1.3265587882258512, 8.40910405349991]
# difference for round 4 is
# 6.041984147493653
# ┌ Info: GpABC rejection simulation. ϵ = 0.01.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\rejection.jl:47
# ┌ Info: GpABC SMC simulation ϵ = 0.005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0007
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 108/1000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 199/2000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# estimated paramter mean is 5.678012176535914, mode is 3.7388205966663453
# estimated paramter mean is 7.322707493432249, mode is 4.1961293096792245
# true parameters are [12.232693522812873, 19.086765094133437]
# difference for round 5 is
# 13.46688155379138
# ┌ Info: GpABC SMC simulation accepted 289/3000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# ┌ Info: GpABC rejection simulation. ϵ = 0.01.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\rejection.jl:47
# ┌ Info: GpABC SMC simulation ϵ = 0.005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0007
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# estimated paramter mean is 14.423617944647564, mode is 12.421421316825347
# estimated paramter mean is 16.604108237818792, mode is 14.65171528914474
# true parameters are [7.155413748131085, 6.82144459135928]
# difference for round 6 is
# 12.187177698795576
# ┌ Info: GpABC SMC simulation accepted 143/1000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# ┌ Info: GpABC rejection simulation. ϵ = 0.01.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\rejection.jl:47
# ┌ Info: GpABC SMC simulation ϵ = 0.005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0007
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 124/1000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 261/2000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# estimated paramter mean is 4.642067422860493, mode is 6.283873555702646
# estimated paramter mean is 12.021110007874226, mode is 16.270618523841396
# true parameters are [5.8007323106936015, 15.842463398217653]
# difference for round 7 is
# 3.9931498915250496
# ┌ Info: GpABC rejection simulation. ϵ = 0.01.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\rejection.jl:47
# ┌ Info: GpABC SMC simulation ϵ = 0.005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 82/1000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 161/2000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 247/3000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 0.0007
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 147/1000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 287/2000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# estimated paramter mean is 17.09925496711586, mode is 19.93212750341826
# estimated paramter mean is 4.050448946666444, mode is 5.31826770571633
# true parameters are [12.128605930993203, 2.1440415630961818]
# difference for round 8 is
# 5.323696173941403
# ┌ Info: GpABC rejection simulation. ϵ = 0.01.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\rejection.jl:47
# ┌ Info: GpABC SMC simulation ϵ = 0.005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0007
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 273/1000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 0.0001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 51/1000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 117/2000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 170/3000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 221/4000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# estimated paramter mean is 18.367670590022442, mode is 16.54356348439115
# estimated paramter mean is 10.887279113011537, mode is 9.835169022896899
# true parameters are [17.492348472894818, 10.202439821288753]
# difference for round 9 is
# 1.111392668780999
# ┌ Info: GpABC SMC simulation accepted 279/5000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# ┌ Info: GpABC rejection simulation. ϵ = 0.01.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\rejection.jl:47
# ┌ Info: GpABC SMC simulation ϵ = 0.005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0007
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 122/1000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 278/2000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# estimated paramter mean is 12.016908675212015, mode is 13.97648848670993
# estimated paramter mean is 16.56838389842961, mode is 19.358949777140918
# true parameters are [6.557679692136769, 7.694468666128982]
# difference for round 10 is
# 10.418711659303462

# %%
writedlm("ABC_SMC_final_popn1.txt", final_popns1, ",")
writedlm("ABC_SMC_final_popn2.txt", final_popns2, ",")
writedlm("ABC_SMC_difference_vect_2_params.txt", difference_vect2, ",")
writedlm("ABC_SMC_real_params1.txt", real_param_vect1, ",")
writedlm("ABC_SMC_real_params2.txt", real_param_vect2, ",")

# %%
vals = []
for i in range(1,stop = 10)
    push!(vals,repeat([real_param_vect1[i]],outer = 300))
end
vals = collect(Iterators.flatten(vals))

flatfinpops = collect(Iterators.flatten(final_popns1))

boxplot(vals,flatfinpops, label="", title = "final popns of parameter 1, last epsilon 0.00005", xlab = "real param value", ylab = "estimated param value", size = (700,500))
plot!([1:20], label = "")

# %%
real_param_vect1
# Out:
# 10-element Array{Any,1}:
#  18.20036343779186
#  12.247981302210857
#  15.229086396546778
#   1.3265587882258512
#  12.232693522812873
#   7.155413748131085
#   5.8007323106936015
#  12.128605930993203
#  17.492348472894818
#   6.557679692136769

# %%
final_popns1= Array(CSV.read("ABC_SMC_final_popn1.txt" ))
final_popns2= Array(CSV.read("ABC_SMC_final_popn2.txt" ))
difference_vect2= Array(CSV.read("ABC_SMC_difference_vect_2_params.txt" ))
real_param_vect1= Array(CSV.read("ABC_SMC_real_params1.txt" ))
real_param_vect2=Array(CSV.read("ABC_SMC_real_params2.txt" ));

# %%
param2_run1=final_popns2[1,:]
param2_run2=final_popns2[2,:]
param2_run3=final_popns2[3,:]
param2_run4=final_popns2[4,:]
param2_run5=final_popns2[5,:]
param2_run6=final_popns2[6,:]
param2_run7=final_popns2[7,:]
param2_run8=final_popns2[8,:]
param2_run9=final_popns2[9,:];

# %%
vals = []
for i in range(1,stop = 9)
    push!(vals,repeat([real_param_vect2[i]],outer = 300))
end
vals = collect(Iterators.flatten(vals))

# flatfinpops = collect(Iterators.flatten(final_popns2))
flatfinpops = collect(Iterators.flatten(Array([param2_run1,param2_run2,param2_run3,param2_run4,param2_run5,param2_run6,param2_run7,param2_run8,param2_run9])))

boxplot(vals,flatfinpops, label="", title = "final popns of parameter 2, last epsilon 0.00005", xlab = "real param value", ylab = "estimated param value", size = (700,500))
plot!([1:20], label = "")

# %%
param1_run1=final_popns1[1,:]
param1_run2=final_popns1[2,:]
param1_run3=final_popns1[3,:]
param1_run4=final_popns1[4,:]
param1_run5=final_popns1[5,:]
param1_run6=final_popns1[6,:]
param1_run7=final_popns1[7,:]
param1_run8=final_popns1[8,:]
param1_run9=final_popns1[9,:];


vals = []
for i in range(1,stop = 9)
    push!(vals,repeat([real_param_vect1[i]],outer = 300))
end
vals = collect(Iterators.flatten(vals))

# flatfinpops = collect(Iterators.flatten(final_popns1))
flatfinpops = collect(Iterators.flatten(Array([param1_run1,param1_run2,param1_run3,param1_run4,param1_run5,param1_run6,param1_run7,param1_run8,param1_run9])))

boxplot(vals,flatfinpops, label="", title = "final popns of parameter 1, last epsilon 0.00005", xlab = "real param value", ylab = "estimated param value", size = (700,500))
plot!([1:20], label = "")
