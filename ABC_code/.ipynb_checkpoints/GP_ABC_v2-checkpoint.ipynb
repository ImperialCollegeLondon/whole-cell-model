# %%
using GpABC,OrdinaryDiffEq, Distances, Distributions, Plots, StatsBase, Printf, ODE, DifferentialEquations, Statistics, ModelingToolkit, CSV
using DelimitedFiles
import Base.Iterators
include("setup_ABC.jl")

gr()
# Out:
# Plots.GRBackend()

# %%
function log_euclidean(x,y)
    output = sqrt(sum((log10.(x.+0.00001) - log10.(y.+0.00001)) .^ 2))
    return (output/size(x)[1]) #average by the length of the vector
end
# Out:
# log_euclidean (generic function with 1 method)

# %%
@parameters t

@variables s_out(t) rmr(t) em(t) rmq(t) rmt(t) et(t) rmm(t) mt(t) mm(t) q(t) si(t) mq(t) mr(t) r(t) NH4(t) nit_mrna(t) nit_mrna_ribo(t) nit(t) NH4_ex(t) N(t) a(t) AA(t) AA_prot(t) AA_mrna(t) AA_mrna_ribo(t)

#############check the last parameter k_ribo_a
###############

@parameters k_cat_AA k_a_NH4 k_NH4 k_a_AA k_NH4_AA k_a #these are the parameters to be varied in ABC
gam= (gmax*a*AA)/(k_ribo_a*k_ribo_a_AA+k_ribo_a_AA*a+k_ribo_AA_a*AA+a*AA) #updated gamma equation that uses both ATP and AA
ttrate= (rmq + rmr + rmt + rmm + nit_mrna_ribo+AA_mrna_ribo)*gam #total translation rate (sum of the mRNA/ribosome complexes times translation rate)
lam= ttrate/M #lambda is the growth rate
nucat= em*vm*si/(Km + abs(si))
AA_vo = ((k_cat_AA*2*a*NH4)/(k_a_NH4*k_a))/(1+(1+(AA/k_a_AA))+(NH4/k_a_NH4)+(1+(AA/k_NH4_AA))+(NH4/k_NH4))
new_AA = AA_vo*AA_prot
AA_a_use = new_AA*2 #each AA produced uses x number of ATP molecules
AA_NH4_use = new_AA*2 #each AA produced uses 2 NH4 molecules
export_rate = 0 #export rate of NH4
fixation = 0
death_rate = 0
k_ribo_a_AA = 10000.0
k_ribo_AA_a = 10000.0
k_ribo_a = 10.0

@derivatives D'~t

eqs = [
    D(s_out)~ 0 #((-et*vt*s_out/(Kt+s_out))*N)-ds*s_out+(export_rate*NH4*50)+1e7
    D(rmr)~ kb*r*mr-ku*rmr-(gam/nr)*rmr-lam*rmr
    D(em)~ (gam/nx)*rmm-lam*em
    D(rmq)~ kb*r*mq-ku*rmq-(gam/nx)*rmq-lam*rmq
    D(rmt)~ kb*r*mt-ku*rmt-gam/nx*rmt-lam*rmt
    D(et)~ (gam/nx)*rmt-lam*et
    D(rmm)~ kb*r*mm-ku*rmm-gam/nx*rmm-lam*rmm
    D(mt)~ (we*a/(thetax+a))+ku*rmt+(gam/nx)*rmt-kb*r*mt-dm*mt-lam*mt
    D(mm)~ (we*a/(thetax+a))+ku*rmm+(gam/nx)*rmm-kb*r*mm-dm*mm-lam*mm
    D(q)~ (gam/nx)*rmq-lam*q
    D(si)~ (et*vt*s_out/(Kt+s_out))-nucat-lam*si
    D(mq)~ (wq*a/(thetax+a)/(1+(q/Kq)^nq))+ku*rmq+(gam/nx)*rmq-kb*r*mq-dm*mq-lam*mq
    D(mr)~ (wr*a/(thetar+a))+ku*rmr+(gam/nr)*rmr-kb*r*mr-dm*mr-lam*mr
    D(r)~ ku*rmr+ku*rmt+ku*rmm+ku*rmq+(gam/nr)*rmr+(gam/nr)*rmr+(gam/nx)*rmt+(gam/nx)*rmm+(gam/nx)*rmq-kb*r*mr-kb*r*mt-kb*r*mm-kb*r*mq+ku*nit_mrna_ribo+(gam/nx)*nit_mrna_ribo-kb*r*nit_mrna+ku*AA_mrna_ribo+(gam/nx)*AA_mrna_ribo-kb*r*AA_mrna-lam*r
    D(NH4)~ 0 #fixation*nit-export_rate*NH4-lam*NH4-AA_NH4_use+2.3e6
    D(nit_mrna)~ 0 #(v_nit*a/(thetax + a))+(ku*nit_mrna_ribo)+(gam/nx*nit_mrna_ribo)-(kb*r*nit_mrna)-(dm*nit_mrna)-(lam*nit_mrna) #num of free nitrogenase coding mRNA
    D(nit_mrna_ribo)~ 0 #(kb*r*nit_mrna)-(ku*nit_mrna_ribo)-(gam/nx*nit_mrna_ribo)-(lam*nit_mrna_ribo) #num of nit mRNA-ribosome complexes
    D(nit)~ 0 #(gam/nx)*nit_mrna_ribo-lam*nit #num of nitrogenase proteins
    D(NH4_ex)~ 0 #(export_rate*NH4)#total num of NH4 molecules exported this timestep
    D(N)~ 0 #lam*N-death_rate*N #the change in num of bacterial cells instead of just loss to dilution
    D(a)~ ns*nucat-ttrate-fixation*nit-AA_a_use-lam*a
    D(AA)~ new_AA-ttrate-lam*AA
    D(AA_prot)~ (gam/nx)*AA_mrna_ribo-lam*AA_prot
    D(AA_mrna)~ ((w_AA*a/(thetax+a)))+(ku*AA_mrna_ribo)+(gam/nx*AA_mrna_ribo)-(kb*r*AA_mrna)-(dm*AA_mrna)-(lam*AA_mrna)
    D(AA_mrna_ribo)~ (kb*r*AA_mrna)-(ku*AA_mrna_ribo)-(gam/nx*AA_mrna_ribo)-(lam*AA_mrna_ribo)
];

println("System defined successfully")
# Out:
# System defined successfully

# %%
de = ODESystem(eqs, t, [s_out, rmr, em, rmq, rmt, 
        et, rmm, mt, mm, q, si, mq, mr, r, NH4, nit_mrna,
        nit_mrna_ribo, nit, NH4_ex, N, a, AA, AA_prot,
        AA_mrna, AA_mrna_ribo],[k_cat_AA,k_a_NH4 ,k_NH4, k_a_AA, k_NH4_AA, k_a])

f = ODEFunction(de)
p = [10.0,10.0,10.0,10.0,10.0,10.0]
burn_in_prob_abc = ODEProblem(f, init, (0.,10000.0),p) #set up the burn in problem

println("burning in model")
sol = solve(burn_in_prob_abc)
println("success")
step_num = size(sol,2)
final_state =sol[step_num] #run the burn in stage and collect the end state to use as new initial values

prob_abc = ODEProblem(f, final_state, (0.,10000.0),p) #the problem to run ABC on using the burned in initial values
# Out:
# burning in model
# success
# ODEProblem with uType Array{Float64,1} and tType Float64. In-place: true
# timespan: (0.0, 10000.0)
# u0: [1.0e11, 1433.7935898638818, 547.7276435794657, 1352.8302553986343, 7.160976755336487, 547.7276435794676, 7.16097675533649, 39.131453539252924, 39.13145353925297, 103475.06368697481  …  3.2845105566973926e-14, -3.242118686375807e-14, 0.0, 0.0, 1.0, 879.6320760648405, 4.328441256015495e9, 119095.04047006265, 8508.539047716775, 1557.0454156898122]

# %%
function simulator_function_lm(params, time1= 10000.0)
    global k_cat_AA = params[1]
    global k_a_NH4 = 10. #params[2]
    global k_NH4 = 10. #params[3]
    global k_a_AA = 10. #params[4]
    global k_NH4_AA = 10.# params[5]
    global k_a = 10. #params[6]
    prob = ODEProblem(AA_simple,init,(0.,time1))
    sol = ODE.solve(prob, saveat = 1.)
    return Array{Float64, 2}(sol)
end
# Out:
# simulator_function_lm (generic function with 2 methods)

# %%
population_colors=["#FF2F4E", "#D0001F", "#A20018", "#990017", "#800013"]

threshold_schedule = [0.01,0.005,0.001, 0.0007, 0.0005, 0.0001];
priors = [Uniform(0., 20.0)]#, Uniform(0.,20.0), Uniform(0., 20.0)]#,
#     Uniform(2., 30.), Uniform(2., 30.), Uniform(2., 30.)]
n_particles = 300

random_vect = []
estimated_vect = []
difference_vect = []
# Out:
# 0-element Array{Any,1}

# %%
params_lm = rand(1)*20
results = simulator_function_lm(params_lm);

#run abc smc to try and recreate the 3 random param values
sim_abcsmc_res = SimulatedABCSMC(results,
    simulator_function_lm,
    priors,
    threshold_schedule,
    n_particles,
    distance_function = log_euclidean,
    max_iter=convert(Int, 2e6),
    write_progress=true)

mean1 = mean(sim_abcsmc_res.population[6][:,1])
mode1 = mode(sim_abcsmc_res.population[6][:,1])
# Out:
# ┌ Info: GpABC rejection simulation. ϵ = 0.01.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\rejection.jl:47
# ┌ Info: GpABC SMC simulation ϵ = 0.005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0007
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 0.0005
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 299/1000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 0.0001
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 201/1000 particles.
# └ @ GpABC C:\Users\leann\.julia\packages\GpABC\1GAUU\src\abc\smc.jl:238
# 17.767158774248827

# %%
sim_abcsmc_res.n_tries #[0.1, 0.07, 0.05, 0.03, 0.01,0.005] 
#only the 0.005 was low enough to need refuse some particles, the others are accepting all particles
# Out:
# 6-element Array{Int64,1}:
#   300
#   300
#   300
#   300
#   300
#  1485

# %%
plot(sim_abcsmc_res)
vline!(params_lm)

# %%
mean1 = mean(sim_abcsmc_res.population[6][:,1])
mode1 = mode(sim_abcsmc_res.population[6][:,1])

println("mean is $mean1")
println("mode is $mode1")
# Out:
# mean is 11.44441340471229
# mode is 14.714638481664117

# %%
param_vect = [0.5, 10.2, 19.5]
for i in range(1,stop = 3)
println(param_vect[i])
end
# Out:
# 0.5
# 10.2
# 19.5

# %%
for i in range(1,stop = 3)

#generate dummy data with 3 random params between 0 and 20
params_lm = param_vect[i]
results = simulator_function_lm(params_lm);

#run abc smc to try and recreate the 3 random param values
sim_abcsmc_res = SimulatedABCSMC(results,
    simulator_function_lm,
    priors,
    threshold_schedule,
    n_particles,
    distance_function = log_euclidean,
    max_iter=convert(Int, 2e6),
    write_progress=true)

mean1 = mean(sim_abcsmc_res.population[6][:,1])
mode1 = mode(sim_abcsmc_res.population[6][:,1])

    ##pull out maximum as well as the mean of the final pop
    
# mean2 =mean(sim_abcsmc_res.population[6][:,2])
# mean3 = mean(sim_abcsmc_res.population[6][:,3])
println("estimated paramters are")
println(mean1)#," ", mean2, " ",mean3)
push!(estimated_vect, mean1)
println("true parameters are")
println(params_lm)
push!(random_vect, params_lm)
println("difference for round $i is")
println(euclidean([mean1],params_lm)) #println(euclidean([mean1,mean2,mean3],params_lm))
push!(difference_vect,euclidean([mean1],params_lm))
    
end
# Out:
# estimated paramters are
# 8.523712024433895
# true parameters are
# [5.7406781155062925]
# difference for round 1 is
# 2.783033908927602
# estimated paramters are
# 8.192033389481209
# true parameters are
# [17.969374896018216]
# difference for round 2 is
# 9.777341506537008
# estimated paramters are
# 11.126227740170584
# true parameters are
# [15.201990173350953]
# difference for round 3 is
# 4.075762433180369
# estimated paramters are
# 7.579536842759411
# true parameters are
# [15.208267605398426]
# difference for round 4 is
# 7.628730762639015
# estimated paramters are
# 7.150547555328322
# true parameters are
# [3.68959082500826]
# difference for round 5 is
# 3.4609567303200626
# estimated paramters are
# 6.398919327766902
# true parameters are
# [14.910915709954352]
# difference for round 6 is
# 8.511996382187451
# estimated paramters are
# 6.4562835778484535
# true parameters are
# [18.297847925259777]
# difference for round 7 is
# 11.841564347411325
# estimated paramters are
# 13.35130659150699
# true parameters are
# [4.054908878019332]
# difference for round 8 is
# 9.296397713487657
# estimated paramters are
# 12.835978767730797
# true parameters are
# [2.269917946050235]
# difference for round 9 is
# 10.566060821680562
# estimated paramters are
# 8.273433012952786
# true parameters are
# [8.138971833227448]
# difference for round 10 is
# 0.13446117972533855
# estimated paramters are
# 15.700554813403885
# true parameters are
# [17.553941894693562]
# difference for round 11 is
# 1.8533870812896769
# estimated paramters are
# 8.797983704570754
# true parameters are
# [8.186431500609231]
# difference for round 12 is
# 0.6115522039615229
# estimated paramters are
# 12.812182288364875
# true parameters are
# [2.391464543043802]
# difference for round 13 is
# 10.420717745321074
# estimated paramters are
# 5.7842643353848455
# true parameters are
# [13.031171772078931]
# difference for round 14 is
# 7.2469074366940855
# estimated paramters are
# 13.54439610497
# true parameters are
# [18.155545720562746]
# difference for round 15 is
# 4.611149615592746
# estimated paramters are
# 11.214379575740939
# true parameters are
# [11.824991971975468]
# difference for round 16 is
# 0.6106123962345293
# estimated paramters are
# 9.301625635977558
# true parameters are
# [12.377975273944607]
# difference for round 17 is
# 3.0763496379670485
# estimated paramters are
# 11.564682020873704
# true parameters are
# [16.486658644602166]
# difference for round 18 is
# 4.921976623728462
# estimated paramters are
# 8.243723258354168
# true parameters are
# [16.004552899753868]
# difference for round 19 is
# 7.760829641399701
# estimated paramters are
# 13.10780000236316
# true parameters are
# [15.57534895876525]
# difference for round 20 is
# 2.4675489564020907
# estimated paramters are
# 7.568848750114698
# true parameters are
# [16.55724298995022]
# difference for round 21 is
# 8.98839423983552
# estimated paramters are
# 14.163614309812434
# true parameters are
# [13.31634201184604]
# difference for round 22 is
# 0.8472722979663949
# estimated paramters are
# 15.696233738180878
# true parameters are
# [4.2448798270350485]
# difference for round 23 is
# 11.45135391114583
# estimated paramters are
# 11.462949607333638
# true parameters are
# [11.761348466283344]
# difference for round 24 is
# 0.29839885894970664
# estimated paramters are
# 9.840013774731212
# true parameters are
# [5.57867401733636]
# difference for round 25 is
# 4.261339757394851
# estimated paramters are
# 9.870198441731429
# true parameters are
# [9.740815325326878]
# difference for round 26 is
# 0.1293831164045507
# estimated paramters are
# 11.822343613534064
# true parameters are
# [7.728592592383348]
# difference for round 27 is
# 4.093751021150717
# estimated paramters are
# 14.976391725575137
# true parameters are
# [14.38842502714046]
# difference for round 28 is
# 0.587966698434677
# estimated paramters are
# 8.310835398703395
# true parameters are
# [18.693120313734344]
# difference for round 29 is
# 10.382284915030949
# estimated paramters are
# 9.478598056731492
# true parameters are
# [10.5464531941095]
# difference for round 30 is
# 1.0678551373780074
# estimated paramters are
# 4.949376835548665
# true parameters are
# [0.7763021730441588]
# difference for round 31 is
# 4.173074662504506
# estimated paramters are
# 11.62143871387824
# true parameters are
# [11.685845618875028]
# difference for round 32 is
# 0.06440690499678858
# estimated paramters are
# 6.406573013488208
# true parameters are
# [14.063938250039572]
# difference for round 33 is
# 7.657365236551364
# estimated paramters are
# 7.4077782651565505
# true parameters are
# [12.688980273423912]
# difference for round 34 is
# 5.281202008267361
# estimated paramters are
# 14.625245430217337
# true parameters are
# [12.73037782109875]
# difference for round 35 is
# 1.8948676091185863
# estimated paramters are
# 12.019808331979526
# true parameters are
# [10.90038030975117]
# difference for round 36 is
# 1.1194280222283552
# estimated paramters are
# 5.081797870595866
# true parameters are
# [19.828071323982623]
# difference for round 37 is
# 14.746273453386756
# estimated paramters are
# 12.859319296365971
# true parameters are
# [10.023446406695582]
# difference for round 38 is
# 2.835872889670389
# estimated paramters are
# 10.992735766037892
# true parameters are
# [17.130109618366248]
# difference for round 39 is
# 6.137373852328356
# estimated paramters are
# 14.793649790806654
# true parameters are
# [11.902760977381632]
# difference for round 40 is
# 2.890888813425022
# estimated paramters are
# 7.973967418422699
# true parameters are
# [6.45523036521964]
# difference for round 41 is
# 1.5187370532030595
# estimated paramters are
# 9.091098185845123
# true parameters are
# [1.323329469136616]
# difference for round 42 is
# 7.767768716708507
# estimated paramters are
# 10.343647406608442
# true parameters are
# [2.6196327238040507]
# difference for round 43 is
# 7.724014682804391
# estimated paramters are
# 10.013395166541578
# true parameters are
# [7.550702534354179]
# difference for round 44 is
# 2.462692632187399
# estimated paramters are
# 9.849758724505083
# true parameters are
# [9.532016729965513]
# difference for round 45 is
# 0.3177419945395705
# estimated paramters are
# 8.224245830131553
# true parameters are
# [10.113797485852016]
# difference for round 46 is
# 1.8895516557204637
# estimated paramters are
# 7.477886645872473
# true parameters are
# [2.1638738814159764]
# difference for round 47 is
# 5.314012764456496
# estimated paramters are
# 9.926425748749594
# true parameters are
# [15.960059436899554]
# difference for round 48 is
# 6.03363368814996
# estimated paramters are
# 6.611973021580197
# true parameters are
# [5.305057849264712]
# difference for round 49 is
# 1.3069151723154855
# estimated paramters are
# 10.579617949130412
# true parameters are
# [7.755516309323709]
# difference for round 50 is
# 2.8241016398067034

# %% [markdown]
# ## to do 23/03/20
#
# pick 3 values, one at each edge of prior and one in centre. pause random values for now, do random one decided epsilon schedule
#
# check the acceptance rate
#
# decrease final epsilon, look for convergence of mean, mode and median
#
# is the final posterior maximum to be near true value??
#
# pull out maximum as well as the mean of the final pop, scatter plot of mean and mode vs real value
#
#     increase bin nums until it starts to become noisy, find middle ground of bin size
#
# ask Suhail about using servers and GPU on laptop

# %%
writedlm("ABC_SMC_differences.txt", difference_vect, ",")

# %%
random_vect= collect(Iterators.flatten(random_vect))
# Out:
# 54-element Array{Float64,1}:
#  19.608404820961102
#   6.559671528880546
#   3.4225029227479364
#   4.615715985338009
#   5.7406781155062925
#  17.969374896018216
#  15.201990173350953
#  15.208267605398426
#   3.68959082500826
#  14.910915709954352
#  18.297847925259777
#   4.054908878019332
#   2.269917946050235
#   ⋮
#  17.130109618366248
#  11.902760977381632
#   6.45523036521964
#   1.323329469136616
#   2.6196327238040507
#   7.550702534354179
#   9.532016729965513
#  10.113797485852016
#   2.1638738814159764
#  15.960059436899554
#   5.305057849264712
#   7.755516309323709

# %%
histogram(difference_vect, bins= 10)

# %%
paired_values = collect(zip(random_vect, estimated_vect))
paired_values = sort(paired_values);

# %%
scatter(random_vect, estimated_vect,xlim= (0,20), ylim = (0,20))

# %%
paired_values
# Out:
# 54-element Array{Tuple{Float64,Any},1}:
#  (0.7763021730441588, 4.949376835548665)
#  (1.323329469136616, 9.091098185845123)
#  (2.1638738814159764, 7.477886645872473)
#  (2.269917946050235, 12.835978767730797)
#  (2.391464543043802, 12.812182288364875)
#  (2.6196327238040507, 10.343647406608442)
#  (3.4225029227479364, 8.009539043057972)
#  (3.68959082500826, 7.150547555328322)
#  (4.054908878019332, 13.35130659150699)
#  (4.2448798270350485, 15.696233738180878)
#  (4.615715985338009, 10.06644691650888)
#  (5.305057849264712, 6.611973021580197)
#  (5.57867401733636, 9.840013774731212)
#  ⋮
#  (15.960059436899554, 9.926425748749594)
#  (16.004552899753868, 8.243723258354168)
#  (16.486658644602166, 11.564682020873704)
#  (16.55724298995022, 7.568848750114698)
#  (17.130109618366248, 10.992735766037892)
#  (17.553941894693562, 15.700554813403885)
#  (17.969374896018216, 8.192033389481209)
#  (18.155545720562746, 13.54439610497)
#  (18.297847925259777, 6.4562835778484535)
#  (18.693120313734344, 8.310835398703395)
#  (19.608404820961102, 7.087564118272932)
#  (19.828071323982623, 5.081797870595866)

# %%
x = random_vect
y = estimated_vect
scatter(x,y, xlim = (0,20), ylim = (0,20),
    xlab = "real value",
    ylab = "estimated value",
    legend = false )
plot!(range(1,stop =20))

# %%
scatter(random_vect, difference_vect, ylab = "difference", xlab ="real value")
# Out:
# BoundsError: attempt to access 52-element Array{Float64,1} at index [53]
#
# Stacktrace:
#  [1] getindex at .\array.jl:744 [inlined]
#  [2] gr_draw_markers(::Plots.Series, ::Array{Float64,1}, ::Array{Float64,1}, ::Tuple{Float64,Float64}, ::Int64) at C:\Users\leann\.julia\packages\Plots\qZHsp\src\backends\gr.jl:348
#  [3] gr_draw_markers(::Plots.Series, ::Array{Float64,1}, ::Array{Float64,1}, ::Tuple{Float64,Float64}) at C:\Users\leann\.julia\packages\Plots\qZHsp\src\backends\gr.jl:333
#  [4] gr_display(::Plots.Subplot{Plots.GRBackend}, ::Measures.Length{:mm,Float64}, ::Measures.Length{:mm,Float64}, ::Array{Float64,1}) at C:\Users\leann\.julia\packages\Plots\qZHsp\src\backends\gr.jl:1633
#  [5] gr_display(::Plots.Plot{Plots.GRBackend}, ::String) at C:\Users\leann\.julia\packages\Plots\qZHsp\src\backends\gr.jl:713
#  [6] _show(::Base.GenericIOBuffer{Array{UInt8,1}}, ::MIME{Symbol("image/svg+xml")}, ::Plots.Plot{Plots.GRBackend}) at C:\Users\leann\.julia\packages\Plots\qZHsp\src\backends\gr.jl:1949
#  [7] show(::Base.GenericIOBuffer{Array{UInt8,1}}, ::MIME{Symbol("image/svg+xml")}, ::Plots.Plot{Plots.GRBackend}) at C:\Users\leann\.julia\packages\Plots\qZHsp\src\output.jl:199
#  [8] #sprint#339(::Nothing, ::Int64, ::typeof(sprint), ::Function, ::MIME{Symbol("image/svg+xml")}, ::Vararg{Any,N} where N) at .\strings\io.jl:105
#  [9] sprint(::Function, ::MIME{Symbol("image/svg+xml")}, ::Vararg{Any,N} where N) at .\strings\io.jl:101
#  [10] _ijulia_display_dict(::Plots.Plot{Plots.GRBackend}) at C:\Users\leann\.julia\packages\Plots\qZHsp\src\ijulia.jl:53
#  [11] display_dict(::Plots.Plot{Plots.GRBackend}) at C:\Users\leann\.julia\packages\Plots\qZHsp\src\init.jl:83
#  [12] #invokelatest#1 at .\essentials.jl:709 [inlined]
#  [13] invokelatest at .\essentials.jl:708 [inlined]
#  [14] execute_request(::ZMQ.Socket, ::IJulia.Msg) at C:\Users\leann\.julia\packages\IJulia\F1GUo\src\execute_request.jl:112
#  [15] #invokelatest#1 at .\essentials.jl:709 [inlined]
#  [16] invokelatest at .\essentials.jl:708 [inlined]
#  [17] eventloop(::ZMQ.Socket) at C:\Users\leann\.julia\packages\IJulia\F1GUo\src\eventloop.jl:8
#  [18] (::IJulia.var"#15#18")() at .\task.jl:333

# %%
difference_vect
# Out:
# 52-element Array{Any,1}:
#   4.587036120310035
#   5.450730931170871
#   2.783033908927602
#   9.777341506537008
#   4.075762433180369
#   7.628730762639015
#   3.4609567303200626
#   8.511996382187451
#  11.841564347411325
#   9.296397713487657
#  10.566060821680562
#   0.13446117972533855
#   1.8533870812896769
#   ⋮
#   6.137373852328356
#   2.890888813425022
#   1.5187370532030595
#   7.767768716708507
#   7.724014682804391
#   2.462692632187399
#   0.3177419945395705
#   1.8895516557204637
#   5.314012764456496
#   6.03363368814996
#   1.3069151723154855
#   2.8241016398067034
